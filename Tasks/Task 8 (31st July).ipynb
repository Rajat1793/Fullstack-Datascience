# %% [raw]
# #task 2 - Superstore_USA
#
# 1 . load this data in sql and in pandas with a relation in sql
# 2 . while loading this data you dont have to create a table manually you can use any automated approach to create a table and load a data in bulk in table
# 3 . Find out how return that we ahve recived and with a product id
# 4 . try  to join order and return data both in sql and pandas
# 5 . Try to find out how many unique customer that we have
# 6 . try to find out in how many regions we are selling a product and who is a manager for a respective region
# 7 . find out how many different differnet shipement mode that we have and what is a percentage usablity of all the shipment mode with respect to dataset
# 8 . Create a new coulmn and try to find our a diffrence between order date and shipment date
# 9 . base on question number 8 find out for which order id we have shipment duration more than 10 days
# 10 . Try to find out a list of a returned order which sihpment duration was more then 15 days and find out that region manager as well
# 11 . Gorup by region and find out which region is more profitable
# 12 . Try to find out overalll in which country we are giving more didscount
# 13 . Give me a list of unique postal code
# 14 . which customer segement is more profitalble find it out .
# 15 . try to find out the 10th most loss making product catagory .
# 16 . Try to find out 10 top  product with highest margins

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1 . load this data in sql and in pandas with a relation in sql

# %%
# order data
order_data = pd.read_excel("/Users/rajaiswal/Desktop/learning/Fullstack_Datascience_Ineuron/DataFiles/Superstore_USA.xlsx", sheet_name='Orders')
order_data.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# ...

# %%
# return data
return_data = pd.read_excel("/Users/rajaiswal/Desktop/learning/Fullstack_Datascience_Ineuron/DataFiles/Superstore_USA.xlsx", sheet_name='Returns')
return_data.head()
# Out:
#    Order ID    Status
# 0        65  Returned
# 1       612  Returned
# 2       614  Returned
# 3       678  Returned
# 4       710  Returned

# %%
# manager data
manager_data = pd.read_excel("/Users/rajaiswal/Desktop/learning/Fullstack_Datascience_Ineuron/DataFiles/Superstore_USA.xlsx", sheet_name='Users')
manager_data.head()
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %%
order_data.dtypes
# Out:
# Row ID                           int64
# Order Priority                  object
# Discount                       float64
# Unit Price                     float64
# Shipping Cost                  float64
# Customer ID                      int64
# Customer Name                   object
# Ship Mode                       object
# Customer Segment                object
# Product Category                object
# Product Sub-Category            object
# Product Container               object
# Product Name                    object
# Product Base Margin            float64
# Region                          object
# State or Province               object
# City                            object
# Postal Code                      int64
# Order Date              datetime64[ns]
# Ship Date               datetime64[ns]
# Profit                         float64
# Quantity ordered new             int64
# Sales                          float64
# Order ID                         int64
# dtype: object

# %% [markdown]
# ## 3 . Find out how many return that we have recived and with a product id

# %%
orderid = pd.DataFrame(order_data[['Order ID', 'Product Name']])
returnid = pd.DataFrame(return_data['Order ID'])
pd.merge(orderid, returnid)
# Out:
#     Order ID                                       Product Name
# 0       9895              Dixon My First Ticonderoga Pencil, #2
# 1      13959                                          Avery 493
# 2      13959                              EcoTones® Memo Sheets
# 3      36038                                          Newell 35
# 4      39490                  Staples SlimLine Pencil Sharpener
# ..       ...                                                ...
# 93      7107  Snap-A-Way® Black Print Carbonless Ruled Speed...
# 94      7107  Recycled Steel Personal File for Standard File...
# 95     42823                                         Xerox 1980
# 96     13638                                   TDK 4.7GB DVD+RW
# 97     47109                        SAFCO Folding Chair Trolley
#
# [98 rows x 2 columns]

# %% [markdown]
# ## 4 . try  to join order and return data both in sql and pandas

# %%
orders_returns = order_data.join(return_data, lsuffix="Order", rsuffix='return')
orders_returns
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %% [markdown]
# ## 5 . Try to find out how many unique customer that we have

# %%
unique_customer = pd.DataFrame(order_data['Customer Name'].unique(), columns=['Customer Name'])
unique_customer
# Out:
#         Customer Name
# 0     Janice Fletcher
# 1       Bonnie Potter
# 2      Ronnie Proctor
# 3        Dwight Hwang
# 4           Leon Gill
# ...               ...
# 2698    Marc McDaniel
# 2699      Marvin Reid
# 2700    Florence Gold
# 2701   Frederick Cole
# 2702    Tammy Buckley
#
# [2703 rows x 1 columns]

# %% [markdown]
# ## 6 . try to find out in how many regions we are selling a product and who is a manager for a respective region

# %%
# unique_prod = pd.DataFrame(order_data['Product Name'].unique(),columns=['Product Name'])
region = pd.DataFrame(order_data[['Region','Product Name']])
manager = pd.DataFrame(manager_data[['Region','Manager']])
manager = pd.merge(region, manager, on='Region')
manager
# Out:
#        Region                                       Product Name Manager
# 0     Central                                           Avery 49   Chris
# 1     Central  Howard Miller 12-3/4 Diameter Accuwave DS ™ Wa...   Chris
# 2     Central                                         Newell 321   Chris
# 3     Central                                         Newell 351   Chris
# 4     Central           OIC Colored Binder Clips, Assorted Sizes   Chris
# ...       ...                                                ...     ...
# 9421    South           Staples Copy Paper (20Lb. and 84 Bright)     Sam
# 9422    South            O'Sullivan 3-Shelf Heavy-Duty Bookcases     Sam
# 9423    South                  Logitech Cordless Access Keyboard     Sam
# 9424    South                      Contemporary Wood/Metal Frame     Sam
# 9425    South  Universal Premium White Copier/Laser Paper (20...     Sam
#
# [9426 rows x 3 columns]

# %% [markdown]
# ## 7 . find out how many different differnet shipement mode that we have and what is a percentage usablity of all the shipment mode with respect to dataset

# %%
k = pd.DataFrame(order_data["Ship Mode"])
Reg_Air = (len(k[k["Ship Mode"] == "Regular Air"])/len(k))*100
Express_Air = (len(k[k["Ship Mode"] == "Express Air"])/len(k))*100
Delivery_Truck = (len(k[k["Ship Mode"] == "Delivery Truck"])/len(k))*100
print("Mode :Regular Air Percentage =",Reg_Air,"\n","Mode :Express Air Percentage =",Express_Air,"\n","Mode :Delivery Truck Percentage =",Delivery_Truck)
# Out:
# Mode :Regular Air Percentage = 74.64460004243581
#  Mode :Express Air Percentage = 11.744112030553786
#  Mode :Delivery Truck Percentage = 13.611287927010396

# %% [markdown]
# ## 8 . Create a new coulmn and try to find our a diffrence between order date and shipment date

# %%
order_data['Delivery_Time(Days)'] = pd.DataFrame(order_data["Ship Date"]- order_data["Order Date"])
order_data.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#   State or Province       City Postal Code  Order Date  Ship Date    Profit  \
# ...

# %% [markdown]
# ## 9 . base on question number 8 find out for which order id we have shipment duration more than 10 days

# %%
#Converting timedelta format to str/object
order_data["Delivery_Time(Days)"] = order_data["Delivery_Time(Days)"].astype(str)
order_data
# Strip "days" from "Delivery_Time(Days)" column
order_data["Delivery_Time(Days)"] = order_data["Delivery_Time(Days)"].str.replace("days","")

# #Converting to int format to perform operations
order_data["Delivery_Time(Days)"] = order_data["Delivery_Time(Days)"].astype(int)

order_data[order_data["Delivery_Time(Days)"] > 10]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 643    18246       Critical      0.05       11.09           5.25          250
# 1548   23091         Medium      0.04      100.98           7.18          595
# 1549   23092         Medium      0.09        6.48           7.49          595
# 1678   20703  Not Specified      0.07      130.98          30.00          637
# 1679   20704  Not Specified      0.09       55.98           4.86          637
# 1680   20705  Not Specified      0.08      115.99           4.23          637
# 1697    2703  Not Specified      0.07      130.98          30.00          640
# 1698    2704  Not Specified      0.09       55.98           4.86          640
# 1699    2705  Not Specified      0.08      115.99           4.23          640
# 2515   18060            Low      0.02        2.21           1.00          964
# 5548   21603  Not Specified      0.02        5.58           1.99         2048
# ...

# %% [markdown]
# ## 10 . Try to find out a list of a returned order which sihpment duration was more then 15 days and find out that region manager as well

# %%
#inner join to find common orders
return_orders = pd.merge(order_data,return_data,how = "inner")

#finding number of days
return_orders["Delivery_Time(Days)"] = order_data["Ship Date"] - order_data["Order Date"]

#converting column to str/object type
return_orders["Delivery_Time(Days)"] = return_orders["Delivery_Time(Days)"].astype(str)

#removing the substring "day"
return_orders["Delivery_Time(Days)"] = return_orders["Delivery_Time(Days)"].str.replace("days","")

#Converting to int to perform operations
return_orders["Delivery_Time(Days)"] = return_orders["Delivery_Time(Days)"].astype(int)

return_orders[return_orders["Delivery_Time(Days)"] > 15 ]
# Out:
# Empty DataFrame
# Columns: [Row ID, Order Priority, Discount, Unit Price, Shipping Cost, Customer ID, Customer Name, Ship Mode, Customer Segment, Product Category, Product Sub-Category, Product Container, Product Name, Product Base Margin, Region, State or Province, City, Postal Code, Order Date, Ship Date, Profit, Quantity ordered new, Sales, Order ID, Delivery_Time(Days), Status]
# Index: []
#
# [0 rows x 26 columns]

# %% [markdown]
# ## 11 . Gorup by region and find out which region is more profitable

# %%
max_profit_region = order_data[["Region","Profit"]].groupby("Region").sum().reset_index()
max_profit_region[max_profit_region["Profit"] == max(max_profit_region["Profit"])]
# Out:
#     Region         Profit
# 0  Central  519825.567067

# %% [markdown]
# ## 12 . Try to find out overall in which country we are giving more didscount

# %%
max_disc_region = order_data[["Region","Discount"]].groupby("Region").sum().reset_index()
max_disc_region[max_disc_region["Discount"] == max(max_disc_region["Discount"])]
# Out:
#     Region  Discount
# 0  Central    143.06

# %% [markdown]
# ## 13 . Give me a list of unique postal code

# %%
unique_postal = pd.DataFrame(order_data['Postal Code'].unique(), columns=['Postal Code'])
unique_postal
# Out:
#       Postal Code
# 0           60101
# 1           98221
# 2           91776
# 3           95123
# 4            2724
# ...           ...
# 1692         6820
# 1693        60014
# 1694        61832
# 1695        62521
# 1696        26554
#
# [1697 rows x 1 columns]

# %% [markdown]
# ## 14 . which customer segement is more profitalble find it out

# %%
max_profit_seg = order_data[["Customer Segment","Profit"]].groupby("Customer Segment").sum().reset_index()
max_profit_seg[max_profit_seg["Profit"] == max(max_profit_seg["Profit"])]
# Out:
#   Customer Segment         Profit
# 1        Corporate  505538.627783

# %% [markdown]
# ## 15 . try to find out the 10th most loss making product catagory

# %%
pcategory = pd.DataFrame(order_data['Product Category'].unique(), columns=['Product category'])
pcategory
# Out:
#   Product category
# 0  Office Supplies
# 1       Technology
# 2        Furniture

# %% [markdown]
# ## 16 . Try to find out 10 top  product with highest margins

# %%
pdetails = order_data[["Product Base Margin","Product Name"]]
pdetails.sort_values('Product Base Margin', ascending=False)
# Out:
#       Product Base Margin                                       Product Name
# 9145                 0.85                                        Accessory27
# 4756                 0.85                                         Accessory4
# 7607                 0.85                                        Accessory27
# 5672                 0.85                                         Accessory4
# 4168                 0.85                  Sterling Rubber Bands by Alliance
# ...                   ...                                                ...
# 8986                  NaN                        SAFCO Folding Chair Trolley
# 9005                  NaN  SAFCO PlanMaster Heigh-Adjustable Drafting Tab...
# 9352                  NaN                           SAFCO Arco Folding Chair
# 9378                  NaN                     Safco Industrial Wire Shelving
# 9393                  NaN                           SAFCO Arco Folding Chair
#
# [9426 rows x 2 columns]
