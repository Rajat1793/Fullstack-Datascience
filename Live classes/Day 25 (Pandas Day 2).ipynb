# %%
import pandas as pd

# %%
df = pd.read_csv(r'/Users/rajaiswal/Desktop/learning/Fullstack_Datascience_Ineuron/DataFiles/sales_data_final.csv')

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name sales quantity  \
# ...

# %%
df.tail()
# Out:
#       Dress_ID   Style    Price  Rating  Size  Season   NeckLine SleeveLength  \
# 495  713391965  Casual      Low     4.7     M  Spring     o-neck         full
# 496  722565148    Sexy      Low     4.3  free  Summer     o-neck         full
# 497  532874347  Casual  Average     4.7     M  Summer     v-neck         full
# 498  655464934  Casual  Average     4.6     L  winter  boat-neck    sleevless
# 499  919930954  Casual      Low     4.4  free  Summer     v-neck        short
#
#     waiseline  Material  FabricType Decoration Pattern Type  Recommendation
# 495   natural  polyster         NaN        NaN        solid               1
# 496    empire    cotton         NaN        NaN          NaN               0
# 497    empire    cotton         NaN       lace        solid               1
# 498    empire      silk  broadcloth   applique        print               1
# 499    empire    cotton    Corduroy       lace        solid               0

# %%
df.columns
# Out:
# Index(['Dress_ID', 'Style', 'Price', 'Rating', 'Size', 'Season', 'NeckLine',
#        'SleeveLength', 'waiseline', 'Material', 'FabricType', 'Decoration',
#        'Pattern Type', 'Recommendation'],
#       dtype='object')

# %%
# datatype is Series

df['NeckLine']
# Out:
# 0         o-neck
# 1         o-neck
# 2         o-neck
# 3         o-neck
# 4         o-neck
#          ...
# 495       o-neck
# 496       o-neck
# 497       v-neck
# 498    boat-neck
# 499       v-neck
# Name: NeckLine, Length: 500, dtype: object

# %%
# datatype is dataframes

df[['NeckLine']]
# Out:
#       NeckLine
# 0       o-neck
# 1       o-neck
# 2       o-neck
# 3       o-neck
# 4       o-neck
# ..         ...
# 495     o-neck
# 496     o-neck
# 497     v-neck
# 498  boat-neck
# 499     v-neck
#
# [500 rows x 1 columns]

# %%
type(df['NeckLine'])

# Series data type is euivalent to list
# Out:
# pandas.core.series.Series

# %%
# to check different data types inside the dataframes
# objects are nothing but string

df.dtypes
# Out:
# Dress_ID            int64
# Style              object
# Price              object
# Rating            float64
# Size               object
# Season             object
# NeckLine           object
# SleeveLength       object
# waiseline          object
# Material           object
# FabricType         object
# Decoration         object
# Pattern Type       object
# Recommendation      int64
# dtype: object

# %%
# df['Date','Duration']  (Error) we have to pass inside the list
df[['Style','NeckLine']]
# Out:
#        Style   NeckLine
# 0       Sexy     o-neck
# 1     Casual     o-neck
# 2    vintage     o-neck
# 3      Brief     o-neck
# 4       cute     o-neck
# ..       ...        ...
# 495   Casual     o-neck
# 496     Sexy     o-neck
# 497   Casual     v-neck
# 498   Casual  boat-neck
# 499   Casual     v-neck
#
# [500 rows x 2 columns]

# %%
# describe will return records those have numerical data
df.describe()
# Out:
#            Dress_ID      Rating  Recommendation
# count  5.000000e+02  500.000000      500.000000
# mean   9.055417e+08    3.528600        0.420000
# std    1.736190e+08    2.005364        0.494053
# min    4.442820e+08    0.000000        0.000000
# 25%    7.673164e+08    3.700000        0.000000
# 50%    9.083296e+08    4.600000        0.000000
# 75%    1.039534e+09    4.800000        1.000000
# max    1.253973e+09    5.000000        1.000000

# %%
df.dtypes == 'object'
# Out:
# Dress_ID          False
# Style              True
# Price              True
# Rating            False
# Size               True
# Season             True
# NeckLine           True
# SleeveLength       True
# waiseline          True
# Material           True
# FabricType         True
# Decoration         True
# Pattern Type       True
# Recommendation    False
# dtype: bool

# %%
# to filter just the object from the dataframes
# extrating just the object from the list

df.dtypes[df.dtypes == 'object']
# Out:
# Style           object
# Price           object
# Size            object
# Season          object
# NeckLine        object
# SleeveLength    object
# waiseline       object
# Material        object
# FabricType      object
# Decoration      object
# Pattern Type    object
# dtype: object

# %%
# to get the index

df.dtypes[df.dtypes == 'object'].index
# Out:
# Index(['Style', 'Price', 'Size', 'Season', 'NeckLine', 'SleeveLength',
#        'waiseline', 'Material', 'FabricType', 'Decoration', 'Pattern Type'],
#       dtype='object')

# %%
# get the data for above index

df[df.dtypes[df.dtypes == 'object'].index]
# Out:
#        Style    Price  Size  Season   NeckLine SleeveLength waiseline  \
# 0       Sexy      Low     M  Summer     o-neck    sleevless    empire
# 1     Casual      Low     L  Summer     o-neck        Petal   natural
# 2    vintage     High     L  Automn     o-neck         full   natural
# 3      Brief  Average     L  Spring     o-neck         full   natural
# 4       cute      Low     M  Summer     o-neck    butterfly   natural
# ..       ...      ...   ...     ...        ...          ...       ...
# 495   Casual      Low     M  Spring     o-neck         full   natural
# 496     Sexy      Low  free  Summer     o-neck         full    empire
# 497   Casual  Average     M  Summer     v-neck         full    empire
# 498   Casual  Average     L  winter  boat-neck    sleevless    empire
# 499   Casual      Low  free  Summer     v-neck        short    empire
#
#           Material  FabricType  Decoration Pattern Type
# 0              NaN     chiffon     ruffles       animal
# ...

# %%
# describe the string data

df[df.dtypes[df.dtypes == 'object'].index].describe()
# Out:
#          Style    Price Size  Season NeckLine SleeveLength waiseline Material  \
# count      500      498  500     498      497          498       413      372
# unique      13        7    7       8       16           17         4       23
# top     Casual  Average    M  Summer   o-neck    sleevless   natural   cotton
# freq       232      252  177     159      271          223       304      152
#
#        FabricType Decoration Pattern Type
# count         234        264          391
# unique         22         24           14
# top       chiffon       lace        solid
# freq          135         70          203

# %%
# describe the float data

df[df.dtypes[df.dtypes == 'float64'].index].describe()
# Out:
#            Rating
# count  500.000000
# mean     3.528600
# std      2.005364
# min      0.000000
# 25%      3.700000
# 50%      4.600000
# 75%      4.800000
# max      5.000000

# %%
df.Style
# Out:
# 0         Sexy
# 1       Casual
# 2      vintage
# 3        Brief
# 4         cute
#         ...
# 495     Casual
# 496       Sexy
# 497     Casual
# 498     Casual
# 499     Casual
# Name: Style, Length: 500, dtype: object

# %%
df.Style[1:4]
# Out:
# 1     Casual
# 2    vintage
# 3      Brief
# Name: Style, dtype: object

# %%
df['Style'][1:4]
# Out:
# 1     Casual
# 2    vintage
# 3      Brief
# Name: Style, dtype: object

# %%
type(df.Style[1:4])
type(df['Style'][1:4])
# Out:
# pandas.core.series.Series

# %%
type(df['Style'][1:4])
# Out:
# pandas.core.series.Series

# %%
df['FabricType'].isnull()
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 495     True
# 496     True
# 497     True
# 498    False
# 499    False
# Name: FabricType, Length: 500, dtype: bool

# %%
max(df['Rating'])
# Out:
# 5.0

# %%
df['Dress_ID'] == max(df['Rating'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Name: Dress_ID, Length: 500, dtype: bool

# %%
df[df['Rating'] == max(df['Rating'])]
# Out:
#        Dress_ID     Style      Price  Rating  Size  Season        NeckLine  \
# 10   1117293701     party    Average     5.0  free  Summer          o-neck
# 14   1055411544    Casual        Low     5.0     M  Summer       boat-neck
# 17    830467746  bohemian     Medium     5.0  free  Automn          o-neck
# 19   1113221101      Sexy    Average     5.0     M  Automn          o-neck
# 40    943844640     Brief    Average     5.0  free  Spring          v-neck
# 50    841203385      Sexy        Low     5.0  free  Summer          v-neck
# 62   1083779666    Casual    Average     5.0     M  Summer          o-neck
# 65   1019134411    Casual    Average     5.0     M  Automn          v-neck
# 70    864253055  bohemian    Average     5.0  free  Summer          v-neck
# 76    842060995    Casual    Average     5.0    XL  Winter       boat-neck
# 80   1130994272    Casual        Low     5.0     M  Summer          v-neck
# ...

# %%
df[df['Rating'] == max(df['Rating'])]['Dress_ID']
# Out:
# 10     1117293701
# 14     1055411544
# 17      830467746
# 19     1113221101
# 40      943844640
# 50      841203385
# 62     1083779666
# 65     1019134411
# 70      864253055
# 76      842060995
# 80     1130994272
# 82      967999477
# 88     1018110870
# 114    1032990258
# 157     832191944
# 166    1069595866
# 176     956453735
# 196     891631697
# 198     764321904
# 202     981437831
# 203    1036456647
# 210    1043590098
# 211    1091666465
# 224    1074432879
# 228     923983419
# 232    1077555214
# 236     995964089
# 252     682561447
# 260    1053467336
# 266    1066740059
# 287     933951149
# 292    1053002876
# 294     949336768
# 303    1044288976
# 315    1024325244
# 316     841203385
# 323     856139963
# 324    1032982013
# 326     912614690
# 327    1072784739
# 328     945651303
# 358     818295153
# 372     720665176
# 378     876761815
# 393     942245416
# 394     900108476
# 410     932913675
# 413    1052420390
# 424     944641715
# 446     865490824
# ...

# %%
df['Style'] == 'Sexy'
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496     True
# 497    False
# 498    False
# 499    False
# Name: Style, Length: 500, dtype: bool

# %%
df[df['Style'] == 'Sexy']['Price']
# Out:
# 0          Low
# 19     Average
# 20     Average
# 23     Average
# 24     Average
#         ...
# 470    Average
# 475        Low
# 477        Low
# 487    Average
# 496        Low
# Name: Price, Length: 69, dtype: object

# %%
df[(df['Style'] == 'Sexy') & (df['Price']=='Low')]
# Out:
#        Dress_ID Style Price  Rating  Size  Season    NeckLine SleeveLength  \
# 0    1006032852  Sexy   Low     4.6     M  Summer      o-neck    sleevless
# 50    841203385  Sexy   Low     5.0  free  Summer      v-neck    sleevless
# 64   1100974555  Sexy   Low     4.0     S  Automn      o-neck    sleevless
# 82    967999477  Sexy   Low     5.0  free  Spring      o-neck         full
# 88   1018110870  Sexy   Low     5.0     M  Automn      o-neck         full
# 93    876708804  Sexy   Low     4.8     M  Spring      o-neck   halfsleeve
# 99    805438829  Sexy   Low     4.8     L  Summer      v-neck         full
# 122   817870237  Sexy   Low     4.6  free  Spring      o-neck         full
# 123  1078996836  Sexy   Low     0.0  free  Winter      v-neck    sleevless
# 127   893330898  Sexy   Low     4.6  free  Summer      v-neck    sleevless
# 140  1130624045  Sexy   Low     0.0  free  Automn  slash-neck        short
# ...

# %%
df[['Recommendation','Rating']].max()
# Out:
# Recommendation    1.0
# Rating            5.0
# dtype: float64

# %%
df.dtypes
# Out:
# Dress_ID            int64
# Style              object
# Price              object
# Rating            float64
# Size               object
# Season             object
# NeckLine           object
# SleeveLength       object
# waiseline          object
# Material           object
# FabricType         object
# Decoration         object
# Pattern Type       object
# Recommendation      int64
# dtype: object

# %%
pd.to_numeric(df['Dress_ID'])
# Out:
# 0      1006032852
# 1      1212192089
# 2      1190380701
# 3       966005983
# 4       876339541
#           ...
# 495     713391965
# 496     722565148
# 497     532874347
# 498     655464934
# 499     919930954
# Name: Dress_ID, Length: 500, dtype: int64

# %%
df['Rating'].value_counts()
# Out:
# 0.0    120
# 4.7     84
# 4.8     57
# 5.0     55
# 4.6     54
# 4.5     34
# 4.4     27
# 4.9     25
# 4.3     20
# 4.0      7
# 4.2      6
# 4.1      5
# 3.7      2
# 3.6      1
# 3.5      1
# 1.0      1
# 3.0      1
# Name: Rating, dtype: int64

# %%
df.drop(1)

# if we want to delete the record permently from the database we have to use INPLACE= TRUE
df.drop(1, inplace=True)

# %%
df
# Out:
#        Dress_ID     Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852      Sexy      Low     4.6     M  Summer     o-neck
# 2    1190380701   vintage     High     0.0     L  Automn     o-neck
# 3     966005983     Brief  Average     4.6     L  Spring     o-neck
# 4     876339541      cute      Low     4.5     M  Summer     o-neck
# 5    1068332458  bohemian      Low     0.0     M  Summer     v-neck
# ..          ...       ...      ...     ...   ...     ...        ...
# 495   713391965    Casual      Low     4.7     M  Spring     o-neck
# 496   722565148      Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347    Casual  Average     4.7     M  Summer     v-neck
# 498   655464934    Casual  Average     4.6     L  winter  boat-neck
# 499   919930954    Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
# filter based on specific row number

df.loc[[3,5, 7]]
# Out:
#      Dress_ID     Style    Price  Rating  Size  Season NeckLine SleeveLength  \
# 3   966005983     Brief  Average     4.6     L  Spring   o-neck         full
# 5  1068332458  bohemian      Low     0.0     M  Summer   v-neck    sleevless
# 7  1219677488   Novelty  Average     0.0  free  Automn   o-neck        short
#
#   waiseline  Material  FabricType  Decoration Pattern Type  Recommendation
# 3   natural      silk     chiffon  embroidary        print               1
# 5    empire       NaN         NaN         NaN        print               0
# 7   natural  polyster  broadcloth        lace          NaN               0

# %%
# filter based on range row number

df.loc[2:6]
# Out:
#      Dress_ID     Style    Price  Rating Size  Season NeckLine SleeveLength  \
# 2  1190380701   vintage     High     0.0    L  Automn   o-neck         full
# 3   966005983     Brief  Average     4.6    L  Spring   o-neck         full
# 4   876339541      cute      Low     4.5    M  Summer   o-neck    butterfly
# 5  1068332458  bohemian      Low     0.0    M  Summer   v-neck    sleevless
# 6  1220707172    Casual  Average     0.0   XL  Summer   o-neck         full
#
#   waiseline       Material FabricType  Decoration Pattern Type  Recommendation
# 2   natural       polyster        NaN         NaN        print               0
# 3   natural           silk    chiffon  embroidary        print               1
# 4   natural  chiffonfabric    chiffon         bow          dot               0
# 5    empire            NaN        NaN         NaN        print               0
# 6       NaN         cotton        NaN         NaN        solid               0

# %%
df.loc[2:10:2]
# Out:
#       Dress_ID    Style    Price  Rating  Size  Season NeckLine SleeveLength  \
# 2   1190380701  vintage     High     0.0     L  Automn   o-neck         full
# 4    876339541     cute      Low     4.5     M  Summer   o-neck    butterfly
# 6   1220707172   Casual  Average     0.0    XL  Summer   o-neck         full
# 8   1113094204    Flare  Average     0.0  free  Spring   v-neck        short
# 10  1117293701    party  Average     5.0  free  Summer   o-neck         full
#
#    waiseline       Material  FabricType Decoration Pattern Type  \
# 2    natural       polyster         NaN        NaN        print
# 4    natural  chiffonfabric     chiffon        bow          dot
# 6        NaN         cotton         NaN        NaN        solid
# 8     empire         cotton  broadcloth    beading        solid
# 10   natural       polyster  broadcloth       lace        solid
#
#     Recommendation
# 2                0
# 4                0
# 6                0
# 8                1
# ...

# %%
# if we want to see particular from a row and column

df.loc[0:4,['Dress_ID','Style','Price','Rating']]
# Out:
#      Dress_ID    Style    Price  Rating
# 0  1006032852     Sexy      Low     4.6
# 2  1190380701  vintage     High     0.0
# 3   966005983    Brief  Average     4.6
# 4   876339541     cute      Low     4.5

# %%
# iloc understands the default index values not the name value, where as loc understand the name index

df .iloc[0:4, 0:3]
# Out:
#      Dress_ID    Style    Price
# 0  1006032852     Sexy      Low
# 2  1190380701  vintage     High
# 3   966005983    Brief  Average
# 4   876339541     cute      Low

# %%
df.iloc[4:8, 3:5]
# Out:
#    Rating  Size
# 5     0.0     M
# 6     0.0    XL
# 7     0.0  free
# 8     0.0  free

# %%
df2 = df[df =='NaN']

# %%
df2
# Out:
#      Dress_ID Style Price  Rating Size Season NeckLine SleeveLength waiseline  \
# 0         NaN   NaN   NaN     NaN  NaN    NaN      NaN          NaN       NaN
# 2         NaN   NaN   NaN     NaN  NaN    NaN      NaN          NaN       NaN
# 3         NaN   NaN   NaN     NaN  NaN    NaN      NaN          NaN       NaN
# 4         NaN   NaN   NaN     NaN  NaN    NaN      NaN          NaN       NaN
# 5         NaN   NaN   NaN     NaN  NaN    NaN      NaN          NaN       NaN
# ..        ...   ...   ...     ...  ...    ...      ...          ...       ...
# 495       NaN   NaN   NaN     NaN  NaN    NaN      NaN          NaN       NaN
# 496       NaN   NaN   NaN     NaN  NaN    NaN      NaN          NaN       NaN
# 497       NaN   NaN   NaN     NaN  NaN    NaN      NaN          NaN       NaN
# 498       NaN   NaN   NaN     NaN  NaN    NaN      NaN          NaN       NaN
# 499       NaN   NaN   NaN     NaN  NaN    NaN      NaN          NaN       NaN
#
# ...

# %%
# dropna will drop all the row where value is NAN

df2.dropna(inplace=True, axis =1)

# %%
# fillna will fill the value where NAN will be present, we can give anything in value

df.fillna(value =4)
# Out:
#        Dress_ID     Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852      Sexy      Low     4.6     M  Summer     o-neck
# 2    1190380701   vintage     High     0.0     L  Automn     o-neck
# 3     966005983     Brief  Average     4.6     L  Spring     o-neck
# 4     876339541      cute      Low     4.5     M  Summer     o-neck
# 5    1068332458  bohemian      Low     0.0     M  Summer     v-neck
# ..          ...       ...      ...     ...   ...     ...        ...
# 495   713391965    Casual      Low     4.7     M  Spring     o-neck
# 496   722565148      Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347    Casual  Average     4.7     M  Summer     v-neck
# 498   655464934    Casual  Average     4.6     L  winter  boat-neck
# 499   919930954    Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire              4     chiffon     ruffles
# ...

# %%
# groupby creates the object its similar to the SQL group by function

df.groupby('Rating')

# %%
# if we want to group data by rating
df.groupby('Rating').mean()
# Out:
#             Dress_ID  Recommendation
# Rating
# 0.0     1.079519e+09        0.394958
# 1.0     1.001751e+09        0.000000
# 3.0     1.119361e+09        0.000000
# 3.5     1.066274e+09        0.000000
# 3.6     9.034264e+08        1.000000
# 3.7     9.647863e+08        0.500000
# 4.0     1.002544e+09        0.285714
# 4.1     8.383911e+08        0.800000
# 4.2     9.327091e+08        0.666667
# 4.3     8.317789e+08        0.400000
# 4.4     7.763344e+08        0.222222
# 4.5     8.748917e+08        0.382353
# 4.6     7.989839e+08        0.481481
# 4.7     8.115577e+08        0.404762
# 4.8     8.443566e+08        0.421053
# 4.9     8.207621e+08        0.480000
# 5.0     9.629673e+08        0.509091

# %%
df.groupby('Rating')['Recommendation'].mean()
# Out:
# Rating
# 0.0    0.394958
# 1.0    0.000000
# 3.0    0.000000
# 3.5    0.000000
# 3.6    1.000000
# 3.7    0.500000
# 4.0    0.285714
# 4.1    0.800000
# 4.2    0.666667
# 4.3    0.400000
# 4.4    0.222222
# 4.5    0.382353
# 4.6    0.481481
# 4.7    0.404762
# 4.8    0.421053
# 4.9    0.480000
# 5.0    0.509091
# Name: Recommendation, dtype: float64
