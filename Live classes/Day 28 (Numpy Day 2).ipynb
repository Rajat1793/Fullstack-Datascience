# %%
import numpy as np
import pandas as pd
import seaborn as sns
import cufflinks as cf
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('iris')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df.iplot()
# Out:
# <div>                            <div id="ee60a2ee-664b-4aa2-854c-5e84411d1b72" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.plot(kind = 'area', alpha = 0.5, stacked = False)
# Out:
# <AxesSubplot:>

# %%
df.plot.scatter(x = 'sepal_length', y = 'sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
# (x axis, y-axis, color, size of dot)

df.plot.scatter(x = 'sepal_length', y = 'sepal_width', c = 'sepal_width', s = 100)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
df.plot.scatter(x = 'sepal_length', y = 'sepal_width', c = 'sepal_width', s = df['sepal_length']*30)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
df.plot.hexbin(x = 'sepal_length', y = 'petal_length', gridsize=15)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.hexbin(x = 'sepal_length', y = 'petal_length', gridsize=15, cmap='viridis')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
from mpl_toolkits import mplot3d

# %%
x = np.linspace(-1, 6, 30)

# %%
x
# Out:
# array([-1.        , -0.75862069, -0.51724138, -0.27586207, -0.03448276,
#         0.20689655,  0.44827586,  0.68965517,  0.93103448,  1.17241379,
#         1.4137931 ,  1.65517241,  1.89655172,  2.13793103,  2.37931034,
#         2.62068966,  2.86206897,  3.10344828,  3.34482759,  3.5862069 ,
#         3.82758621,  4.06896552,  4.31034483,  4.55172414,  4.79310345,
#         5.03448276,  5.27586207,  5.51724138,  5.75862069,  6.        ])

# %%
y = np.linspace(-1, 6, 30)

# %%
y
# Out:
# array([-1.        , -0.75862069, -0.51724138, -0.27586207, -0.03448276,
#         0.20689655,  0.44827586,  0.68965517,  0.93103448,  1.17241379,
#         1.4137931 ,  1.65517241,  1.89655172,  2.13793103,  2.37931034,
#         2.62068966,  2.86206897,  3.10344828,  3.34482759,  3.5862069 ,
#         3.82758621,  4.06896552,  4.31034483,  4.55172414,  4.79310345,
#         5.03448276,  5.27586207,  5.51724138,  5.75862069,  6.        ])

# %%
z = x + y

# %%
z
# Out:
# array([-2.        , -1.51724138, -1.03448276, -0.55172414, -0.06896552,
#         0.4137931 ,  0.89655172,  1.37931034,  1.86206897,  2.34482759,
#         2.82758621,  3.31034483,  3.79310345,  4.27586207,  4.75862069,
#         5.24137931,  5.72413793,  6.20689655,  6.68965517,  7.17241379,
#         7.65517241,  8.13793103,  8.62068966,  9.10344828,  9.5862069 ,
#        10.06896552, 10.55172414, 11.03448276, 11.51724138, 12.        ])

# %%
ax = plt.axes(projection = '3d')
ax.plot3D(x, y, z)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
# Out:
# Text(0.5, 0, 'z')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
ax = plt.axes(projection = '3d')
ax.plot3D(df['sepal_length'],df['petal_length'], df['sepal_width'])
ax.set_xlabel('sepal_length')
ax.set_ylabel('petal_length')
ax.set_zlabel('sepal_width')
# Out:
# Text(0.5, 0, 'sepal_width')

# %%
df.plot(figsize = (20, 10))
# Out:
# <AxesSubplot:>

# %%
df.head().plot(kind = 'bar', figsize = (20, 10))
# Out:
# <AxesSubplot:>

# %%
df.head().plot(kind = 'barh', figsize = (20, 10))
# Out:
# <AxesSubplot:>

# %%
df.plot(kind = 'hist', figsize = (20, 10))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.hist(figsize= (20, 10), color = '#51E1ED', alpha = .8)
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
df.iplot(x = 'sepal_length', y = 'sepal_width', kind = 'scatter', size = 12, mode = 'markers')
# Out:
# <div>                            <div id="a1b7a556-3809-4f89-bdc8-e2f3092d207a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x = 'sepal_length', y = 'sepal_width',z= 'petal_length', kind = 'bubble3d', size = 'sepal_length')
# Out:
# <div>                            <div id="7d6b3666-4f0a-4ac2-81be-beea38b26c81" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1 = sns.load_dataset('tips')

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df1.plot(x= 'total_bill', y = 'tip', kind = 'scatter', figsize = (20, 10))
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
df1.iplot(x= 'total_bill', y = 'tip', kind = 'scatter', mode = 'markers')
# Out:
# <div>                            <div id="9c493f17-8258-4e7e-9111-fcf251dc86c1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = df1)

# %%
df1['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
# based on creteria we can use hue

sns.relplot(x = 'total_bill', y = 'tip', data = df1, hue = 'smoker')

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = df1, hue = 'sex', style = 'smoker')

# %%
# seperate graph based on time = lunch or dinner

sns.relplot(x = 'total_bill', y = 'tip', data = df1, hue = 'sex', style = 'smoker', col = 'time')

# %%
sns.relplot(x = 'sepal_length', y = 'sepal_width', data = df, col = 'species')

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = df1, hue = 'sex', style = 'smoker', col = 'day')

# %%
sns.catplot(x= 'day', y= 'total_bill', data = df1)

# %%
sns.pairplot(df1)

# %%
sns.pairplot(df)

# %%
df.scatter_matrix()
# Out:
# <div>                            <div id="6999b882-d912-4861-9692-a21bc76e6d18" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1.scatter_matrix()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [127], in <cell line: 1>()
# ----> 1 df1.scatter_matrix()
#
# File /opt/anaconda3/lib/python3.9/site-packages/cufflinks/plotlytools.py:1280, in _scatter_matrix(self, theme, bins, color, size, asFigure, **iplot_kwargs)
#    1259 def _scatter_matrix(self,theme=None,bins=10,color='grey',size=2, asFigure=False, **iplot_kwargs):
#    1260 	"""
#    1261 	Displays a matrix with scatter plot for each pair of
#    1262 	Series in the DataFrame.
#    (...)
#    1278 			Keyword arguments to pass through to `iplot`
#    1279 	"""
# -> 1280 	sm=tools.scatter_matrix(self,theme=theme,bins=bins,color=color,size=size)
#    1281 	if asFigure:
#    1282 		return sm
#
# File /opt/anaconda3/lib/python3.9/site-packages/cufflinks/tools.py:1020, in scatter_matrix(df, theme, bins, color, size)
#    1018 			figs.append(fig)
#    1019 		else:
# ...

# %%
sns.jointplot(x= df1.total_bill, y = df1.tip)

# %%
sns.jointplot(x= df1.total_bill, y = df1.tip, kind = 'hex')

# %%
sns.pairplot(df1)

# %%
sns.regplot(x = df1.total_bill, y = df1.tip
# figure size in sns
sns.set(rc = {'figure.figsize': (20, 10)})

# %%
import plotly.express as px
fig = px.scatter(df1, x= 'total_bill', y = "tip")
fig.show()
# Out:
# <div>                            <div id="2775ded2-c477-4ead-8acb-1631b768bda0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2775ded2-c477-4ead-8acb-1631b768bda0")) {                    Plotly.newPlot(                        "2775ded2-c477-4ead-8acb-1631b768bda0",                        [{"hovertemplate":"total_bill=%{x}<br>tip=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[16.99,10.34,21.01,23.68,24.59,25.29,8.77,26.88,15.04,14.78,10.27,35.26,15.42,18.43,14.83,21.58,10.33,16.29,16.97,20.65,17.92,20.29,15.77,39.42,19.82,17.81,13.37,12.69,21.7,19.65,9.55,18.35,15.06,20.69,17.78,24.06,16.31,16.93,18.69,31.27,16.04,17.46,13.94,9.68,30.4,18.29,2
# ...

# %%
fig = px.bar(df1, x= 'sex', y = "total_bill", color ='smoker', barmode = 'group' )
fig.show()
# Out:
# <div>                            <div id="11312a42-6942-4208-9e12-b049d993da77" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("11312a42-6942-4208-9e12-b049d993da77")) {                    Plotly.newPlot(                        "11312a42-6942-4208-9e12-b049d993da77",                        [{"alignmentgroup":"True","hovertemplate":"smoker=No<br>sex=%{x}<br>total_bill=%{y}<extra></extra>","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"textposition":"auto","x":["Female","Male","Male","Male","Female","Male","Male","Male","Male","Male","Male","Female","Male","Male","Female","Male","Female","Male","Female","Male","Male","Female","Female","Male","Male","Male","Male
# ...
